# %%
import itertools
import pandas as pd

# Definir los parámetros
params = {
    "tree_shape": ["regular", "triangular"],
    "branch_arrangement": ["staggered", "aligned"],
    "number_of_layers": [2, 6, 12],
    "chitin_layer_thickness": [0.05, 0.1, 0.3],
    "air_layer_thickness": [0.01, 0.1, 0.4],
    "air_gap_x": [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 1.0, 1.5, 2.0],
    "ridge_total_width": [0.24, 0.4, 0.6, 1.0, 1.5]
}

# Parámetros fijos (se añaden después)
fixed_params = {
    "substrate_thickness_z": 0.164,
    "air_gap_below_z": 1.8,
    "ridge_trunk_width": 0.12
}

# Generar todas las combinaciones
keys, values = zip(*params.items())
combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]

# Crear un DataFrame para gestionar todo
df = pd.DataFrame(combinations)

# Añadir columnas fijas y un ID único
for k, v in fixed_params.items():
    df[k] = v

df['sim_id'] = df.index.map(lambda x: f"sim_{x:05d}") # sim_00001, sim_00002...

# %%
df
# Out:
#       tree_shape branch_arrangement  number_of_layers  chitin_layer_thickness  \
# 0        regular          staggered                 2                    0.05
# 1        regular          staggered                 2                    0.05
# 2        regular          staggered                 2                    0.05
# 3        regular          staggered                 2                    0.05
# 4        regular          staggered                 2                    0.05
# ...          ...                ...               ...                     ...
# 7015  triangular            aligned                12                    0.30
# 7016  triangular            aligned                12                    0.30
# 7017  triangular            aligned                12                    0.30
# 7018  triangular            aligned                12                    0.30
# 7019  triangular            aligned                12                    0.30
#
# ...
